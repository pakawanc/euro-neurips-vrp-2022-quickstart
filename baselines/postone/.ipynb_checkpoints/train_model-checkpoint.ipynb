# %%
import pandas as pd
import numpy as np
import os

# %%
data_dir = '/Users/pakawanc/OneDrive - Chulalongkorn University/Project/VR/euro-neurips-vrp-2022-quickstart/misc'

# %%
df_greedy = pd.read_csv(os.path.join(data_dir,'data_greedy.csv'))
df_postone = pd.read_csv(os.path.join(data_dir,'data_postone_collectpostone_1.csv'))

print('len df_greedy : ',len(df_greedy))
print('len df_postone : ',len(df_postone))
# Out:
# len df_greedy :  500
# len df_postone :  10

# %%
print('len df_greedy : ',len(df_greedy))
print('len df_postone : ',len(df_postone))
# Out:
# len df_greedy :  500
# len df_postone :  10

# %%
df = df_post
# Out:
#    avg_dur_with_must_dispatch  min_dur_with_must_dispatch  rank_duration_1  \
# 0                1.000000e+09                1.000000e+09         0.010239
# 1                1.000000e+09                1.000000e+09         0.018684
# 2                1.000000e+09                1.000000e+09         0.018207
# 3                1.000000e+09                1.000000e+09         0.064027
# 4                1.000000e+09                1.000000e+09         0.022982
#
#    rank_duration_2  rank_duration_3  rank_duration_4  rank_duration_5  \
# 0         0.016674         0.021890         0.025367         0.034283
# 1         0.047933         0.048222         0.051748         0.074084
# 2         0.029080         0.033662         0.040127         0.049176
# 3         0.093010         0.116294         0.127408         0.134242
# 4         0.083906         0.098208         0.098208         0.103200
#
#    rank_duration_6  rank_duration_7  rank_duration_8  ...  demand_left  \
# 0         0.034283         0.039366         0.047697  ...          2.0
# 1         0.077157         0.083780         0.086031  ...         11.0
# 2         0.075376         0.081763         0.089647  ...         13.0
# 3         0.135787         0.148000         0.157393  ...          6.0
# 4         0.107341         0.111024         0.111024  ...          5.0
#
#    avg_demand  total_demand_must_dispatch  capacity  rem_epoch    cost  \
# 0    7.465347                         0.0     160.0        7.0  609765
# 1    7.465347                         0.0     160.0        7.0  609526
# 2    7.465347                         0.0     160.0        7.0  608953
# 3    7.465347                         0.0     160.0        7.0  608834
# 4    7.465347                         0.0     160.0        7.0  609733
#
#    instance_seed                                   instance  postpone_epoch  \
# 0              1  ORTEC-VRPTW-ASYM-a53ed404-d1-n406-k25.txt               1
# 1              1  ORTEC-VRPTW-ASYM-a53ed404-d1-n406-k25.txt               1
# 2              1  ORTEC-VRPTW-ASYM-a53ed404-d1-n406-k25.txt               1
# 3              1  ORTEC-VRPTW-ASYM-a53ed404-d1-n406-k25.txt               2
# 4              1  ORTEC-VRPTW-ASYM-a53ed404-d1-n406-k25.txt               2
#
#    postpone_seed
# 0              1
# 1              2
# 2              3
# 3              1
# 4              2
#
# [5 rows x 112 columns]

# %%
# !ls "/Users/pakawanc/OneDrive - Chulalongkorn University/Project/VR/euro-neurips-vrp-2022-quickstart/misc"
# Out:
# checkpoint.pkl                    data_postone_collectpostone_1.csv
# data_greedy.csv                   num_epoch.csv
